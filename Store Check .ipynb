# %%
# Run this cell to render a mitosheet
# See mito's documentation here: https://docs.trymito.io/how-to/creating-a-mitosheet
# Join our Slack for support here: https://join.slack.com/t/trymito/shared_invite/zt-1h6t163v7-xLPudO7pjQNKccXz7h7GSg

import mitosheet
mitosheet.sheet(analysis_to_replay="id-josnanhvxo")
# Out:
# MitoWidget(analysis_data_json='{"analysisName": "id-jbpmjtbsca", "analysisToReplay": {"analysisName": "id-josn…

# %%
from mitosheet import *; register_analysis("id-josnanhvxo");
    
# Imported Untitled1.ipynb
import pandas as pd
Untitled1_ipynb = pd.read_csv(r'/Users/eduardocampos/code/dxclemente/blast-from-the-forecast/notebooks/Untitled1.ipynb', sep='{')

# Imported sales_train.csv
import pandas as pd
sales_train = pd.read_csv(r'/Users/eduardocampos/code/dxclemente/blast-from-the-forecast/raw_data/sales_train.csv')

# Pivoted into sales_train
tmp_df = sales_train[['shop_id', 'date_block_num', 'item_cnt_day']]
pivot_table = tmp_df.pivot_table(
    index=['date_block_num'],
    columns=['shop_id'],
    values=['item_cnt_day'],
    aggfunc={'item_cnt_day': ['sum']}
)
pivot_table = pivot_table.set_axis([flatten_column_header(col) for col in pivot_table.keys()], axis=1)
sales_train_pivot = pivot_table.reset_index()

# Pivoted into sales_train
tmp_df = sales_train[['shop_id', 'date_block_num', 'item_cnt_day']]
pivot_table = tmp_df.pivot_table(
    index=['date_block_num'],
    columns=['shop_id'],
    values=['item_cnt_day'],
    aggfunc={'item_cnt_day': ['sum']}
)
pivot_table = pivot_table.set_axis([flatten_column_header(col) for col in pivot_table.keys()], axis=1)
sales_train_pivot = pivot_table.reset_index()

# Pivoted into sales_train
tmp_df = sales_train[['item_cnt_day', 'item_id', 'date_block_num']]
pivot_table = tmp_df.pivot_table(
    index=['date_block_num'],
    columns=['item_id'],
    values=['item_cnt_day'],
    aggfunc={'item_cnt_day': ['sum']}
)
pivot_table = pivot_table.set_axis([flatten_column_header(col) for col in pivot_table.keys()], axis=1)
sales_train_pivot_1 = pivot_table.reset_index()

# Pivoted into sales_train
tmp_df = sales_train[['shop_id', 'date', 'item_cnt_day']]
pivot_table = tmp_df.pivot_table(
    index=['date'],
    columns=['shop_id'],
    values=['item_cnt_day'],
    aggfunc={'item_cnt_day': ['sum']}
)
pivot_table = pivot_table.set_axis([flatten_column_header(col) for col in pivot_table.keys()], axis=1)
sales_train_pivot = pivot_table.reset_index()

# Changed date to dtype datetime
import pandas as pd
sales_train_pivot['date'] = pd.to_datetime(sales_train_pivot['date'], format='%d.%m.%Y', errors='coerce')

# Changed date to dtype datetime
import pandas as pd
sales_train['date'] = pd.to_datetime(sales_train['date'], format='%d.%m.%Y', errors='coerce')

# Pivoted into sales_train
tmp_df = sales_train[['item_cnt_day', 'date', 'item_id']]
pivot_table = tmp_df.pivot_table(
    index=['date'],
    columns=['item_id'],
    values=['item_cnt_day'],
    aggfunc={'item_cnt_day': ['sum']}
)
pivot_table = pivot_table.set_axis([flatten_column_header(col) for col in pivot_table.keys()], axis=1)
sales_train_pivot = pivot_table.reset_index()

# Added column new-column-deu0
sales_train.insert(1, 'new-column-deu0', 0)

# Imported items.csv
import pandas as pd
items = pd.read_csv(r'/Users/eduardocampos/code/dxclemente/blast-from-the-forecast/raw_data/items.csv')

# Renamed columns item_group
sales_train.rename(columns={'new-column-deu0': 'item_group'}, inplace=True)

# Set formula of item_group
sales_train['item_group'] = MONTH(sales_train['date'])

# Renamed columns month
sales_train.rename(columns={'item_group': 'month'}, inplace=True)

# Pivoted into sales_train
tmp_df = sales_train[['shop_id', 'month', 'item_cnt_day']]
pivot_table = tmp_df.pivot_table(
    index=['month'],
    columns=['shop_id'],
    values=['item_cnt_day'],
    aggfunc={'item_cnt_day': ['sum']}
)
pivot_table = pivot_table.set_axis([flatten_column_header(col) for col in pivot_table.keys()], axis=1)
sales_train_pivot = pivot_table.reset_index()

# Pivoted into sales_train
tmp_df = sales_train[['shop_id', 'month', 'date_block_num', 'item_cnt_day']]
pivot_table = tmp_df.pivot_table(
    index=['date_block_num', 'month'],
    columns=['shop_id'],
    values=['item_cnt_day'],
    aggfunc={'item_cnt_day': ['sum']}
)
pivot_table = pivot_table.set_axis([flatten_column_header(col) for col in pivot_table.keys()], axis=1)
sales_train_pivot_1 = pivot_table.reset_index()

# Sorted date_block_num in descending order
sales_train = sales_train.sort_values(by='date_block_num', ascending=False, na_position='last')

# Pivoted into sales_train
tmp_df = sales_train[['shop_id', 'date_block_num', 'item_cnt_day']]
pivot_table = tmp_df.pivot_table(
    index=['date_block_num'],
    columns=['shop_id'],
    values=['item_cnt_day'],
    aggfunc={'item_cnt_day': ['sum']}
)
pivot_table = pivot_table.set_axis([flatten_column_header(col) for col in pivot_table.keys()], axis=1)
sales_train_pivot = pivot_table.reset_index()

# Pivoted into sales_train
tmp_df = sales_train[['shop_id', 'month', 'item_cnt_day']]
pivot_table = tmp_df.pivot_table(
    index=['month'],
    columns=['shop_id'],
    values=['item_cnt_day'],
    aggfunc={'item_cnt_day': ['sum']}
)
pivot_table = pivot_table.set_axis([flatten_column_header(col) for col in pivot_table.keys()], axis=1)
sales_train_pivot = pivot_table.reset_index()

# Pivoted into sales_train
tmp_df = sales_train[['shop_id', 'date_block_num', 'item_cnt_day']]
pivot_table = tmp_df.pivot_table(
    index=['date_block_num'],
    columns=['shop_id'],
    values=['item_cnt_day'],
    aggfunc={'item_cnt_day': ['sum']}
)
pivot_table = pivot_table.set_axis([flatten_column_header(col) for col in pivot_table.keys()], axis=1)
sales_train_pivot = pivot_table.reset_index()

# Pivoted into sales_train
tmp_df = sales_train[['shop_id', 'month', 'item_cnt_day']]
pivot_table = tmp_df.pivot_table(
    index=['month'],
    columns=['shop_id'],
    values=['item_cnt_day'],
    aggfunc={'item_cnt_day': ['sum']}
)
pivot_table = pivot_table.set_axis([flatten_column_header(col) for col in pivot_table.keys()], axis=1)
sales_train_pivot = pivot_table.reset_index()

# Imported sales_train.csv
import pandas as pd
sales_train_1 = pd.read_csv(r'/Users/eduardocampos/code/dxclemente/blast-from-the-forecast/raw_data/sales_train.csv')

# Imported test.csv
import pandas as pd
test = pd.read_csv(r'/Users/eduardocampos/code/dxclemente/blast-from-the-forecast/raw_data/test.csv')

# Pivoted into test
tmp_df = test[['shop_id', 'item_id']]
pivot_table = tmp_df.pivot_table(
    index=['shop_id'],
    values=['item_id'],
    aggfunc={'item_id': ['count']}
)
pivot_table = pivot_table.set_axis([flatten_column_header(col) for col in pivot_table.keys()], axis=1)
test_pivot = pivot_table.reset_index()

# Imported sample_submission.csv
import pandas as pd
sample_submission = pd.read_csv(r'/Users/eduardocampos/code/dxclemente/blast-from-the-forecast/raw_data/sample_submission.csv')

# Pivoted into sales_train
tmp_df = sales_train[['item_cnt_day', 'item_id', 'date_block_num']]
pivot_table = tmp_df.pivot_table(
    index=['date_block_num'],
    columns=['item_id'],
    values=['item_cnt_day'],
    aggfunc={'item_cnt_day': ['sum']}
)
pivot_table = pivot_table.set_axis([flatten_column_header(col) for col in pivot_table.keys()], axis=1)
sales_train_pivot_2 = pivot_table.reset_index()

# Pivoted into sales_train
tmp_df = sales_train[['item_cnt_day', 'month', 'item_id', 'date_block_num']]
pivot_table = tmp_df.pivot_table(
    index=['date_block_num', 'month'],
    columns=['item_id'],
    values=['item_cnt_day'],
    aggfunc={'item_cnt_day': ['sum']}
)
pivot_table = pivot_table.set_axis([flatten_column_header(col) for col in pivot_table.keys()], axis=1)
sales_train_pivot_1 = pivot_table.reset_index()

# Pivoted into sales_train
tmp_df = sales_train[['item_cnt_day', 'item_id', 'date_block_num']]
pivot_table = tmp_df.pivot_table(
    index=['date_block_num'],
    columns=['item_id'],
    values=['item_cnt_day'],
    aggfunc={'item_cnt_day': ['count']}
)
pivot_table = pivot_table.set_axis([flatten_column_header(col) for col in pivot_table.keys()], axis=1)
sales_train_pivot_1 = pivot_table.reset_index()

# Pivoted into sales_train
tmp_df = sales_train[['item_cnt_day', 'item_id', 'date_block_num']]
pivot_table = tmp_df.pivot_table(
    index=['date_block_num'],
    columns=['item_id'],
    values=['item_cnt_day'],
    aggfunc={'item_cnt_day': ['count']}
)
pivot_table = pivot_table.set_axis([flatten_column_header(col) for col in pivot_table.keys()], axis=1)
sales_train_pivot = pivot_table.reset_index()

# Sorted item_id in ascending order
sales_train = sales_train.sort_values(by='item_id', ascending=True, na_position='first')

# Pivoted into sales_train
tmp_df = sales_train[['item_cnt_day', 'item_id', 'date_block_num']]
pivot_table = tmp_df.pivot_table(
    index=['date_block_num'],
    columns=['item_id'],
    values=['item_cnt_day'],
    aggfunc={'item_cnt_day': ['sum']}
)
pivot_table = pivot_table.set_axis([flatten_column_header(col) for col in pivot_table.keys()], axis=1)
sales_train_pivot = pivot_table.reset_index()

# Filtered shop_id
sales_train = sales_train[sales_train['shop_id'] > 2]

# Filtered item_id
sales_train = sales_train[sales_train['item_id'] > 6400]

# Pivoted into sales_train
tmp_df = sales_train[sales_train['item_id'].notnull()]
tmp_df = tmp_df[['item_cnt_day', 'item_id', 'date_block_num']]
pivot_table = tmp_df.pivot_table(
    index=['date_block_num'],
    columns=['item_id'],
    values=['item_cnt_day'],
    aggfunc={'item_cnt_day': ['sum']}
)
pivot_table = pivot_table.set_axis([flatten_column_header(col) for col in pivot_table.keys()], axis=1)
sales_train_pivot = pivot_table.reset_index()

# Pivoted into sales_train
tmp_df = sales_train[sales_train['date_block_num'] > 22]
tmp_df = tmp_df[['item_cnt_day', 'item_id']]
pivot_table = tmp_df.pivot_table(
    columns=['item_id'],
    values=['item_cnt_day'],
    aggfunc={'item_cnt_day': ['sum']}
)
pivot_table = pivot_table.set_axis([flatten_column_header(col) for col in pivot_table.keys()], axis=1)
sales_train_pivot = pivot_table.reset_index()

# %%
# Imported Untitled1.ipynb
import pandas as pd
Untitled1_ipynb = pd.read_csv(r'/Users/eduardocampos/code/dxclemente/blast-from-the-forecast/notebooks/Untitled1.ipynb', sep='{')

# Imported sales_train.csv
import pandas as pd
sales_train = pd.read_csv(r'/Users/eduardocampos/code/dxclemente/blast-from-the-forecast/raw_data/sales_train.csv')

# Filtered shop_id
sales_train = sales_train[sales_train['shop_id'] == 59]
